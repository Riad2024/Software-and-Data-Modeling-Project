# %%
# Import some python libraries
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns
from scipy import stats
plt.style.use('ggplot')
# Load and Read the CSV file 'Psychological Health and Stability.csv' into a DataFrame
Unique_Dataset = pd.read_csv('Psychological Health and Stability.csv')
# Display the first few rows of the DataFrame
Unique_Dataset.head()
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  1990
# 1  Afghanistan  AFG  1991
# 2  Afghanistan  AFG  1992
# 3  Afghanistan  AFG  1993
# 4  Afghanistan  AFG  1994
#
#    Schizophrenia disorders (share of population) - Sex: Both - Age: Age-standardized  \
# 0                                           0.223206
# 1                                           0.222454
# 2                                           0.221751
# 3                                           0.220987
# 4                                           0.220183
#
#    Depressive disorders (share of population) - Sex: Both - Age: Age-standardized  \
# 0                                           4.996118
# 1                                           4.989290
# 2                                           4.981346
# 3                                           4.976958
# 4                                           4.977782
#
#    Anxiety disorders (share of population) - Sex: Both - Age: Age-standardized  \
# ...

# %% [markdown]
# Markdown: At the very beginning we import some python libraries such as pandas as pd, numpy as np, matplotlib.pylab as plt, seaborn as sns, stats from scipy. To load and read our dataset into thw dataframe we use .read_csv() funtion. Also we use .head() function to show the first few rows from the dataset.

# %%
# Display information about the DataFrame
Unique_Dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5376 entries, 0 to 5375
# Data columns (total 15 columns):
#  #   Column                                                                             Non-Null Count  Dtype
# ---  ------                                                                             --------------  -----
#  0   Entity                                                                             5376 non-null   object
#  1   Code                                                                               5376 non-null   object
#  2   Year                                                                               5376 non-null   int64
#  3   Schizophrenia disorders (share of population) - Sex: Both - Age: Age-standardized  5376 non-null   float64
#  4   Depressive disorders (share of population) - Sex: Both - Age: Age-standardized     5376 non-null   float64
# ...

# %% [markdown]
# Markdown: Here we show the basic information of the dataset with the data type and modules by using .info() function.

# %%
# Generate descriptive statistics for the DataFrame
Unique_Dataset.describe()
# Out:
#               Year  \
# count  5376.000000
# mean   2003.500000
# std       8.078499
# min    1990.000000
# 25%    1996.750000
# 50%    2003.500000
# 75%    2010.250000
# max    2017.000000
#
#        Schizophrenia disorders (share of population) - Sex: Both - Age: Age-standardized  \
# count                                        5376.000000
# mean                                            0.264887
# std                                             0.039950
# min                                             0.188446
# 25%                                             0.231827
# 50%                                             0.271644
# 75%                                             0.284898
# max                                             0.462045
#
#        Depressive disorders (share of population) - Sex: Both - Age: Age-standardized  \
# count                                        5376.000000
# mean                                            3.797826
# ...

# %% [markdown]
# Markdown: At this part we use .describe() function to generate the descriptive statistics Which shows the number of rows, mean value, minimum value, maximum value of all tupls and percentage as well.

# %%
# Group by world university ranking
Unique_Dataset.groupby('Entity')['Entity'].count()
# Out:
# Entity
# Afghanistan       28
# Albania           28
# Algeria           28
# American Samoa    28
# Andorra           28
#                   ..
# Vietnam           28
# World             28
# Yemen             28
# Zambia            28
# Zimbabwe          28
# Name: Entity, Length: 192, dtype: int64

# %% [markdown]
# Markdown: Here we show the number of each entity contains in the dataframe group by entity by using .groupby() function and .count() function.

# %%
Sorted = Unique_Dataset.sort_values('Entity', inplace=False)
# Data Distributing graph of all columns 
plt.figure(figsize=(60, 40))
for i, j in enumerate(Unique_Dataset.columns):
    plt.subplot(5, 5, i+1)
    plt.hist(Sorted[j], color='firebrick', histtype='bar')
    plt.title(str(Unique_Dataset.columns[i]))
    plt.ylabel("Values")

# %% [markdown]
# Markdown: Here, we display the data distributing graphs for all columns. To configure the figure size we use plt.figure() function and then we use "for loop" to get the graph for every column. For subplot we use plt.subplot() function. Then for showing the all histograms we use plt.hist() function and we give the title for each histogram by using plt.title() function.

# %%
# Checking histogram of a specific column
import matplotlib
from matplotlib import pyplot
plt.figure(figsize=(10, 10))
# %matplotlib inline
# Plotting the histogram of Alcohol use disorders 
pyplot.hist(Unique_Dataset['Alcohol use disorders (%)'])
plt.title("Histogram of Alcohol use disorders")
# Display histogram
pyplot.show()

# %% [markdown]
# Markdown: To display the histogram of "Alcohol use disorders" column, first we import matplotlib and pyplot. Then we configure the size of the figure and we use %matplotlib inline. After that we use pyplot.hist() function for the histogram with the title for which we use plt.title() function. Then we use pyplot.show() to display the graph.

# %%
# Statistical test whether Alcohol use disorders normally distributed or not 
from scipy.stats import shapiro
NdTest = Unique_Dataset['Alcohol use disorders (%)']
stat, p=shapiro(NdTest)
print('stat=%.2f, p=%.30f' %(stat, p))
if p> 0.1:
    print('This is a normal distribution')
else:
      print('Not a normal distribution')
# Out:
# stat=0.82, p=0.000000000000000000000000000000
# Not a normal distribution
# C:\Users\riada\anaconda3\lib\site-packages\scipy\stats\_morestats.py:1800: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")

# %% [markdown]
# Markdown: Here, we test the values in "Alcohol use disorders" column are normally distributed or not. For this test we import shapiro from scipy.stats and use the shapiro() function. We will get a message that it is normal distribution or not.

# %%
import matplotlib
from matplotlib import pyplot
#Correlation test of Anxiety
column1 = Unique_Dataset[1:300]['Anxiety disorders (share of population) - Sex: Both - Age: Age-standardized']
column2 = Unique_Dataset[1:300]['Anxiety disorders (%)']
pyplot.plot(column1, column2)
plt.title("Correlation of Anxiety for different category")
plt.xlabel("Anxiety disorders (share of population) - Sex: Both - Age: Age-standardized")
plt.ylabel("Anxiety disorders (%)")
# Display graph
pyplot.show()

# %% [markdown]
# Markdown: Here, we generate the correlation between 'Anxiety disorders (%)' and 'Anxiety disorders (share of population) - Sex: Both - Age: Age-standardized' columns. For this, we use pyplot.plot() to build the graph and give the title. Also we labeled the axes by the column names.

# %%
import matplotlib
from matplotlib import pyplot
#Correlation test of Depression
column1 = Unique_Dataset[1:100]['Depressive disorders (share of population) - Sex: Both - Age: Age-standardized']
column2 = Unique_Dataset[1:100]['Depression (%)']
pyplot.plot(column1, column2)
plt.title("Correlation of Anxiety for different category")
plt.xlabel("Depressive disorders (share of population) - Sex: Both - Age: Age-standardized")
plt.ylabel("Depression (%)")
# Display graph
pyplot.show()

# %% [markdown]
# Markdown: Again, we generate another correlation between 'Depression (%)' and 'Depressive disorders (share of population) - Sex: Both - Age: Age-standardized' columns.

# %%
# Scatter plot of Schizophrenia
import matplotlib.pylab as plt
plt.scatter(Unique_Dataset["Schizophrenia disorders (share of population) - Sex: Both - Age: Age-standardized"], Unique_Dataset["Schizophrenia (%)"], marker='o', c='teal')
plt.title("Scatter plot of Schizophrenia for different category")
plt.xlabel("Schizophrenia (%)")
plt.ylabel("Schizophrenia disorders (share of population) - Sex: Both - Age: Age-standardized")
plt.show()

# %% [markdown]
# Markdown: Here, we display the scatter plot graph of "Schizophrenia (%)" and "Schizophrenia disorders (share of population) - Sex: Both - Age: Age-standardized" columns. For this we use plt.scatter() function to build the graph and we give the title. After giving the labels too we use plt.show() to visualize the graph.

# %%
# Scatter plot of Bipolar disorder using function
import matplotlib.pylab as plt
X = Unique_Dataset["Bipolar disorders (share of population) - Sex: Both - Age: Age-standardized"] 
y = Unique_Dataset["Bipolar disorder (%)"]
def sct(X, y, Xlabel=None, ylabel=None):
    plt.scatter(X, y, marker='o', c='navy')
    plt.title("Scatter plot of Bipolar disorder")
    plt.xlabel(Xlabel)
    plt.ylabel(ylabel)
    return plt.show()
sct(X, y, 'Bipolar disorders (share of population) - Sex: Both - Age: Age-standardized', 'Bipolar disorder (%)')

# %% [markdown]
# Markdown: This is another scatter plot graph of "Bipolar disorder (%)" and "Bipolar disorders (share of population) - Sex: Both - Age: Age-standardized" columns.
